# %%
# Check current transformers version
import transformers
print(f"Transformers version: {transformers.__version__}")
# Out:
# Transformers version: 4.57.1

# %%
# Specify the model name from the Hugging Face Hub
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig, pipeline

model_name = "mistralai/Mistral-7B-Instruct-v0.1"
tokenizer = AutoTokenizer.from_pretrained(model_name)

bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.bfloat16
)

# Load the model
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    quantization_config=bnb_config,
    torch_dtype=torch.bfloat16,
    trust_remote_code=True,
    device_map="auto"
)

# Define your prompt
prompt = "Give me a short introduction to large language models."
 
# Use model
generator = pipeline("text-generation", model=model, tokenizer=tokenizer)

# Generate text
results = generator(prompt, max_new_tokens=100, num_return_sequences=1)

# Print the output
print(results[0]['generated_text'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\transformers\models\auto\auto_factory.py:741, in getattribute_from_module(module, attr)
#     740 try:
# --> 741     return getattribute_from_module(transformers_module, attr)
#     742 except ValueError:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\transformers\models\auto\auto_factory.py:745, in getattribute_from_module(module, attr)
#     744 else:
# --> 745     raise ValueError(f"Could not find {attr} in {transformers_module}!")
#
# ...

# %%
# Upgrade all required packages to latest versions
# !pip install --upgrade pip
# !pip install --upgrade transformers>=4.36.0
# !pip install --upgrade torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# !pip install --upgrade accelerate
# !pip install --upgrade bitsandbytes
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
